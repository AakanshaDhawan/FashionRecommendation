# %% [markdown]
# # Comparision of all the methods

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
li =[['Wk_45', 'Wk_46', 'Wk_47', 'Wk_48', 'Wk_49', 'Wk_50', 'Wk_51', 'Wk_52'],
     [0.03932584269662922, 0.025771428571428574, 0.06019354838709678, 0.03864583333333334, 0.02918279569892472, 0.0328056288478452, 0.035042517006802686, 0.029617346938775508],
     [0.03868290313515032, 0.044652738267023984, 0.04928791757824016, 0.03672475176939462, 0.03651753324333971, 0.03814350630313692, 0.04579202342914079, 0.039067184233000554],
     [0.04711610486891387, 0.06940860215053765, 0.06378787878787877, 0.03788359788359789, 0.06749262536873156, 0.06439775910364146, 0.029457364341085274, 0.05508591065292097]]

# %%
df = pd.DataFrame()
df['weeks'] = li[0]

df['user'] = li[1]
df['item'] = li[2]
df['content'] = li[3]

df
# Out:
#    weeks      user      item   content
# 0  Wk_45  0.039326  0.038683  0.047116
# 1  Wk_46  0.025771  0.044653  0.069409
# 2  Wk_47  0.060194  0.049288  0.063788
# 3  Wk_48  0.038646  0.036725  0.037884
# 4  Wk_49  0.029183  0.036518  0.067493
# 5  Wk_50  0.032806  0.038144  0.064398
# 6  Wk_51  0.035043  0.045792  0.029457
# 7  Wk_52  0.029617  0.039067  0.055086

# %%
#plot for all comparison of map
plt.figure(figsize=(15,6))
plt.plot(df.weeks, df.user, color= 'blue')
plt.plot(df.weeks, df.item, color= 'orange')
plt.plot(df.weeks, df.content, color= 'red')
plt.title("Matrices for Mean Average Percision")
plt.xlabel('2018 Nov-Dec')
plt.ylabel('Mean Average Percision')
plt.legend(['User based collaborative filtering','Item based collaborative filtering','Content based filtering'])
